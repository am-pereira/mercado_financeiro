# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
# ^GSPC = S&P500, ^IXIC = NASDAQ, ^GDAXI = DAX
tickers = ['^GSPC', '^IXIC', '^GDAXI']
ind_data = pd.DataFrame()
for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source='yahoo', start='1997-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                  ^GSPC        ^IXIC       ^GDAXI
# Date
# 1997-01-02  737.010010  1280.699951  2820.810059
# 1997-01-03  748.030029  1310.680054  2863.260010
# 1997-01-06  747.650024  1316.400024  2890.199951
# 1997-01-07  753.229980  1327.729980  2876.340088
# 1997-01-08  748.409973  1320.349976  2904.080078

# %%
ind_data.tail()
# Out:
#                   ^GSPC         ^IXIC        ^GDAXI
# Date
# 2020-08-10  3360.469971  10968.360352  12687.530273
# 2020-08-11  3333.689941  10782.820312  12946.889648
# 2020-08-12  3380.350098  11012.240234  13058.629883
# 2020-08-13  3373.429932  11042.500000  12993.709961
# 2020-08-14  3372.850098  11019.299805  12901.339844

# %%
(ind_data / ind_data.iloc[0] * 100).plot(figsize=(15,6));
plt.show()

# %%
# Retorno simples
ind_returns = (ind_data / ind_data.shift(1)) - 1
ind_returns.tail()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI
# Date
# 2020-08-10  0.002742 -0.003871  0.000998
# 2020-08-11 -0.007969 -0.016916  0.020442
# 2020-08-12  0.013997  0.021276  0.008631
# 2020-08-13 -0.002047  0.002748 -0.004971
# 2020-08-14 -0.000172 -0.002101 -0.007109

# %%
# Retorno simples anual
annual_ind_returns = ind_returns.mean() * 250
annual_ind_returns
# Out:
# ^GSPC     0.083454
# ^IXIC     0.122373
# ^GDAXI    0.077417
# dtype: float64

# %%
# Preço da ação Microsoft em relação aos índices NASDAQ e DOWJONES
tickers = ['MSFT', '^IXIC', '^DJI']
data_2 = pd.DataFrame()
for t in tickers:
    data_2[t] = wb.DataReader(t, data_source='yahoo', start='2007-1-1')['Adj Close']

# %%
data_2.tail()
# Out:
#                   MSFT         ^IXIC          ^DJI
# Date
# 2020-08-10  208.250000  10968.360352  27791.439453
# 2020-08-11  203.380005  10782.820312  27686.910156
# 2020-08-12  209.190002  11012.240234  27976.839844
# 2020-08-13  208.699997  11042.500000  27896.720703
# 2020-08-14  208.899994  11019.299805  27931.019531

# %%
(data_2 / data_2.iloc[0] * 100).plot(figsize=(15, 6));
plt.show()
